# %% [markdown]
# # MOAI 2025 Training
#
# 本題目是 MOAI 2025 的訓練題目
#
# 你將使用 PyTorch 來構建一個卷積神經網絡（CNN）模型，用於識別手寫數字，請按照以下步驟完成任務。
#
# 第一段代碼中的 TaskGrader 是一個評分器，請不要修改。可以點擊代碼塊中左側的深色部分將代碼摺疊。

# %%
# 此部分為評分器，請勿編輯此單元格

import torch
import pandas as pd


class TaskGrader:
    def __init__(self):
        self.q1_1_pass = False
        self.q1_2_pass = False
        self.q1_3_pass = False

        self.q2_1_pass = False
        self.q2_2_pass = False
        self.q2_3_pass = False
        self.q2_4_pass = False
        self.q2_5_pass = False

        self.q3_1_pass = False
        self.q3_2_pass = False

    def q1_1_check(self, images_raw, labels_raw):
        try:
            assert isinstance(images_raw, torch.Tensor), "圖片應該是 torch.Tensor 類型"
            assert images_raw.shape == (60000, 28, 28), f"圖片維度大小應該是 (60000, 28, 28)，現在是{images_raw.shape}"

            assert isinstance(labels_raw, pd.DataFrame), "標籤應該是 pandas DataFrame 類型"
            assert len(labels_raw) == 60000, f"標籤應該有 60000 行，現在是 {len(labels_raw)}"
        except AssertionError as e:
            print("Q1.1未通過:", str(e))
            return

        self.q1_1_pass = True
        print("Q1.1通過 (5分)")

    def q1_2_check(self, images, labels):
        try:
            assert isinstance(images, torch.Tensor), "歸一化後的圖像必須是 torch.Tensor 類型"
            assert isinstance(labels, torch.Tensor), "標籤必須是 torch.Tensor 類型"

            assert -0.1 < images.mean() < 0.1, f"歸一化圖像的均值應接近0，現在是{images.mean()}"
            assert 0.9 < images.std() < 1.1, f"歸一化圖像的標準差應接近1，現在是{images.std()}"
        except AssertionError as e:
            print("Q1.2未通過:", str(e))
            return

        self.q1_2_pass = True
        print("Q1.2通過 (5分)")

    def q1_3_check(self, train_dataset, val_dataset):
        try:
            total_size = len(train_dataset) + len(val_dataset)
            train_ratio = len(train_dataset) / total_size

            assert 0.79 <= train_ratio <= 0.81, f"訓練-驗證集分割應為8:2，現在是{train_ratio:.2f}:{1 - train_ratio:.2f}"
        except AssertionError as e:
            print("Q1.3未通過:", str(e))
            return

        self.q1_3_pass = True
        print("Q1.3通過 (5分)")

    def q2_check(self, model):
        try:
            for name, module in model.named_modules():
                if isinstance(module, torch.nn.Conv2d):
                    self.q2_1_pass = True
                elif isinstance(module, torch.nn.MaxPool2d):
                    self.q2_2_pass = True
                elif any(
                    isinstance(module, act)
                    for act in [
                        torch.nn.ReLU,
                        torch.nn.Sigmoid,
                        torch.nn.Tanh,
                        torch.nn.ELU,
                        torch.nn.LeakyReLU,
                        torch.nn.PReLU,
                    ]
                ):
                    self.q2_3_pass = True
                elif isinstance(module, torch.nn.Linear):
                    if module.out_features == 10:
                        self.q2_4_pass = True
                        
            
            x = torch.randn(1, 28, 28).to(next(model.parameters()).device)
            output = model(x)
            if output.shape[1] == 10:
                self.q2_5_pass = True
                
        except Exception:
            pass

        checks = [
            (self.q2_1_pass, "Q2.1", "模型應包含卷積層", 2),
            (self.q2_2_pass, "Q2.2", "模型應包含池化層", 2),
            (self.q2_3_pass, "Q2.3", "模型應包含激活函數", 2),
            (self.q2_4_pass, "Q2.4", "模型應包含輸出層", 2),
            (self.q2_5_pass, "Q2.5", "未能成功定義前向傳播，輸出分類結果", 7)
        ]
        
        for check in checks:
            if not check[0]:
                print(f"{check[1]}未通過: {check[2]}")
            else:
                print(f"{check[1]}通過 ({check[3]}分)")


    def q3_1_check(self, criterion, optimizer):
        try:
            valid_loss_fns = [
                torch.nn.CrossEntropyLoss,
                torch.nn.NLLLoss,
                torch.nn.MSELoss,
                torch.nn.L1Loss,
                torch.nn.SmoothL1Loss,
                torch.nn.HuberLoss,
                torch.nn.SoftMarginLoss,
                torch.nn.MultiLabelMarginLoss,
                torch.nn.MultiLabelSoftMarginLoss,
            ]

            valid_optimizers = [
                torch.optim.SGD,
                torch.optim.Adam,
                torch.optim.RMSprop,
                torch.optim.Adagrad,
                torch.optim.Adadelta,
                torch.optim.Adamax,
                torch.optim.AdamW,
                torch.optim.SparseAdam,
                torch.optim.ASGD,
                torch.optim.Rprop,
                torch.optim.LBFGS,
                torch.optim.NAdam,
            ]

            is_valid_loss = any(isinstance(criterion, loss_fn) for loss_fn in valid_loss_fns)
            is_valid_optimizer = any(isinstance(optimizer, opt) for opt in valid_optimizers)

            assert is_valid_loss, "必須使用有效的損失函數 (CrossEntropyLoss, NLLLoss, MSELoss 等)"
            assert is_valid_optimizer, "必須使用有效的優化器 (SGD, Adam, RMSprop 等)"

        except Exception as e:
            print("Q3.1未通過:", str(e))
            return

        self.q3_1_pass = True
        print("Q3.1通過 (5分)")

    def q3_2_check(self, train_losses, val_losses, train_accs, val_accs):
        try:
            assert len(train_losses) >= 5, f"應至少訓練5個週期，目前{len(train_losses)}"
            assert len(val_losses) >= 5, f"應至少驗證5個週期，目前{len(val_losses)}"
            assert len(train_accs) >= 5, f"應至少記錄5個週期的訓練準確率，目前{len(train_accs)}"
            assert len(val_accs) >= 5, f"應至少記錄5個週期的驗證準確率，目前{len(val_accs)}"

            assert train_losses[0] > train_losses[-1], "訓練損失應隨着週期減少"

            assert train_accs[-1] > 0.5, f"最終訓練準確率應更高，目前{train_accs[-1]:.2f}"
            assert val_accs[-1] > 0.5, f"最終驗證準確率應更高，目前{val_accs[-1]:.2f}"

        except Exception as e:
            print("Q3.2未通過:", str(e))
            return

        self.q3_2_pass = True
        print("Q3.2通過 (15分)")


task_grader = TaskGrader()

# 此部分為評分器，請勿編輯此單元格

# %% [markdown]
# ### 小題 1：數據讀取與預處理 (15 分)
#
# 數據集包括以下內容
#
# - 訓練圖像數據：train_images.pt (shape: [60000, 28, 28])
# - 訓練標籤數據：train_labels.csv
# - 測試圖像數據：test_images.pt (shape: [10000, 28, 28])
#
# 其中，訓練數據集提供圖像和標籤，測試數據集只提供圖像，不提供標籤
#
# **本題目要求完成以下內容**
#
# 1. 讀取數據集圖片和標籤 (5分)
# 2. 將數據集按 **8:2** 的比例劃分為訓練集和驗證集。 (5分)
# 3. 將圖像數據歸一化並轉換為 Tensor。 (5分)

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, random_split
import pandas as pd

# 讀取數據集，'train-images.pt' 和 'train-labels.csv'
images_raw = torch.load('/kaggle/input/moai-2025-training/train_images.pt', weights_only=False)
labels_raw = pd.read_csv('/kaggle/input/moai-2025-training/train_labels.csv')

# 歸一化數據集並轉換為 torch.Tensor
images = (images_raw.float() - images_raw.float().mean()) / images_raw.float().std()
labels = torch.tensor(labels_raw['label'].values)

# 創建數據集
dataset = TensorDataset(images, labels)

# 按照 8:2 劃分成訓練集和驗證集
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128)

# %%
# 以下代碼執行後可以判斷你的作答是否正確，請勿修改

task_grader.q1_1_check(images_raw, labels_raw)
task_grader.q1_2_check(images, labels)
task_grader.q1_3_check(train_dataset, val_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/1290019795.py in <cell line: 0>()
#       1 # 以下代碼執行後可以判斷你的作答是否正確，請勿修改
#       2
# ----> 3 task_grader.q1_1_check(images_raw, labels_raw)
#       4 task_grader.q1_2_check(images, labels)
#       5 task_grader.q1_3_check(train_dataset, val_dataset)
#
# NameError: name 'task_grader' is not defined

# %% [markdown]
# ### 可視化
#
# 以下是一段將數據集進行可視化的代碼，如果前面的代碼編寫正確，會顯示兩行的圖片，第一行是訓練集，第二行是驗證集

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_samples(loader, title):
    images, labels = next(iter(loader))
    images = images[:5]
    labels = labels[:5]
    
    plt.figure(figsize=(15, 3))
    plt.suptitle(title, fontsize=16)
    
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = images[i].squeeze()
        plt.imshow(img.numpy(), cmap='gray' if img.dim() == 2 else None)
        plt.title(f"Label: {labels[i].item()}")
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# 可視化訓練集樣本
visualize_samples(train_loader, "Training set")

# 可視化驗證集樣本
visualize_samples(val_loader, "Validation set")

# %% [markdown]
# ### 小題 2：構建 CNN 模型 (15 分)
#
# 定義一個簡單的 CNN 模型，滿足以下條件：
#
# 1. 至少包含兩個卷積層 (`nn.Conv2d`) (2分)
# 2. 至少包含兩個池化層 (`nn.MaxPool2d`) (2分)
# 3. 使用激活函數 (`nn.ReLU`, `nn.Sigmoid`, `nn.Tanh`, `nn.ELU`, `nn.LeakyReLU`, `nn.PreLU` 等) (2分)
# 4. 定義輸出層，輸出一個 10 維向量 (對應 10 個類別) (2分)
# 5. 定義前向傳播，將以上所有網絡層連接（7分）

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ImprovedCNN(nn.Module):
    def __init__(self):
        super(ImprovedCNN, self).__init__()
        
        # 特徵提取層
        self.features = nn.Sequential(
            # 第一卷積塊 (輸入: 1x28x28)
            nn.Conv2d(1, 32, kernel_size=3, padding=1),  # 輸出: 32x28x28
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),  # 輸出: 32x14x14
            
            # 第二卷積塊
            nn.Conv2d(32, 64, kernel_size=3, padding=1),  # 輸出: 64x14x14
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),  # 輸出: 64x7x7
            
            # 第三卷積塊 (加深網絡)
            nn.Conv2d(64, 128, kernel_size=3, padding=1),  # 輸出: 128x7x7
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, padding=1)  # 輸出: 128x4x4 (padding=1保持尺寸可被2整除)
        )
        
        # 分類器
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),  # 防止過擬合
            nn.Linear(128 * 4 * 4, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = x.view(-1, 1, 28, 28)  # 確保輸入尺寸
        x = self.features(x)
        x = torch.flatten(x, 1)  # 展平
        x = self.classifier(x)
        return x

# 使用示例
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ImprovedCNN().to(device)
print(model)
# Out:
# ImprovedCNN(
#   (features): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=2048, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
# 以下代碼執行後可以判斷你的作答是否正確，請勿修改

task_grader.q2_check(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/832205343.py in <cell line: 0>()
#       1 # 以下代碼執行後可以判斷你的作答是否正確，請勿修改
#       2
# ----> 3 task_grader.q2_check(model)
#
# NameError: name 'task_grader' is not defined

# %% [markdown]
# ### 小題 3：訓練模型 (20 分)
#
# 1. 選擇損失函數 (`MSELoss`, `CrossEntropyLoss` 等) (2分)
# 2. 選擇優化器（`SGD`, `Adam` 等），並設置學習率。 (3分)
# 3. 模型訓練**至少** 5 個 epoch，並在每個 epoch 結束時分別打印訓練集和驗證集的損失函數和準確率。 (15分)

# %%
from sklearn.metrics import accuracy_score

# 選擇損失函數
criterion = nn.CrossEntropyLoss()

# 選擇優化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

train_losses = []
train_accs = []
val_losses = []
val_accs = []

# 訓練循環
for epoch in range(50):
    model.train()
    for batch_idx, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        preds = outputs.argmax(dim=1)
        train_loss = loss.item()
        train_acc = accuracy_score(labels.cpu().numpy(), preds.cpu().numpy())
        
        # 以下是記錄損失函數和準確率的代碼，不用修改
        if batch_idx % 100 == 0:
            train_losses.append(train_loss)
            train_accs.append(train_acc)
            print(f"Epoch {epoch+1}, Batch {batch_idx}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc * 100:.2f}%")
    
    model.eval()

    val_preds, val_true = [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            outputs = model(images)
            
            val_preds.extend(outputs.argmax(dim=1).cpu().numpy())
            val_true.extend(labels.numpy())

    val_loss = criterion(outputs.cpu(), labels).item()
    val_acc = accuracy_score(val_true, val_preds)
    
    # 以下是記錄損失函數和準確率的代碼，不用修改
    val_accs.append(val_acc)
    val_losses.append(val_loss)
    print(f"Epoch {epoch+1}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc * 100:.2f}%")
# Out:
# Epoch 1, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 1, Batch 100, Train Loss: 0.0241, Train Accuracy: 99.22%
# Epoch 1, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 1, Batch 300, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 1, Val Loss: 0.0000, Val Accuracy: 99.43%
# Epoch 2, Batch 0, Train Loss: 0.0661, Train Accuracy: 99.22%
# Epoch 2, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 2, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 2, Batch 300, Train Loss: 0.0060, Train Accuracy: 99.22%
# Epoch 2, Val Loss: 0.0000, Val Accuracy: 99.51%
# Epoch 3, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 3, Batch 100, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 3, Batch 200, Train Loss: 0.0003, Train Accuracy: 100.00%
# Epoch 3, Batch 300, Train Loss: 0.0003, Train Accuracy: 100.00%
# Epoch 3, Val Loss: 0.0000, Val Accuracy: 99.42%
# Epoch 4, Batch 0, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 4, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 4, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 4, Batch 300, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 4, Val Loss: 0.0000, Val Accuracy: 99.44%
# Epoch 5, Batch 0, Train Loss: 0.0034, Train Accuracy: 100.00%
# Epoch 5, Batch 100, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 5, Batch 200, Train Loss: 0.0002, Train Accuracy: 100.00%
# Epoch 5, Batch 300, Train Loss: 0.0218, Train Accuracy: 99.22%
# Epoch 5, Val Loss: 0.0000, Val Accuracy: 99.44%
# Epoch 6, Batch 0, Train Loss: 0.0002, Train Accuracy: 100.00%
# Epoch 6, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 6, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 6, Batch 300, Train Loss: 0.0014, Train Accuracy: 100.00%
# Epoch 6, Val Loss: 0.0000, Val Accuracy: 99.46%
# Epoch 7, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 7, Batch 100, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 7, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 7, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 7, Val Loss: 0.0000, Val Accuracy: 99.45%
# Epoch 8, Batch 0, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 8, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 8, Batch 200, Train Loss: 0.0004, Train Accuracy: 100.00%
# Epoch 8, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 8, Val Loss: 0.0000, Val Accuracy: 99.44%
# Epoch 9, Batch 0, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 9, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 9, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 9, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 9, Val Loss: 0.0000, Val Accuracy: 99.36%
# Epoch 10, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 10, Batch 100, Train Loss: 0.0205, Train Accuracy: 99.22%
# Epoch 10, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 10, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 10, Val Loss: 0.0001, Val Accuracy: 99.36%
# Epoch 11, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 11, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 11, Batch 200, Train Loss: 0.0260, Train Accuracy: 99.22%
# Epoch 11, Batch 300, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 11, Val Loss: 0.0000, Val Accuracy: 99.46%
# Epoch 12, Batch 0, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 12, Batch 100, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 12, Batch 200, Train Loss: 0.0025, Train Accuracy: 100.00%
# Epoch 12, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 12, Val Loss: 0.0000, Val Accuracy: 99.31%
# Epoch 13, Batch 0, Train Loss: 0.0608, Train Accuracy: 98.44%
# Epoch 13, Batch 100, Train Loss: 0.0059, Train Accuracy: 99.22%
# Epoch 13, Batch 200, Train Loss: 0.0027, Train Accuracy: 100.00%
# Epoch 13, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 13, Val Loss: 0.0000, Val Accuracy: 99.37%
# Epoch 14, Batch 0, Train Loss: 0.0004, Train Accuracy: 100.00%
# Epoch 14, Batch 100, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 14, Batch 200, Train Loss: 0.0102, Train Accuracy: 99.22%
# Epoch 14, Batch 300, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 14, Val Loss: 0.0000, Val Accuracy: 99.45%
# Epoch 15, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 15, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 15, Batch 200, Train Loss: 0.0002, Train Accuracy: 100.00%
# Epoch 15, Batch 300, Train Loss: 0.0265, Train Accuracy: 99.22%
# Epoch 15, Val Loss: 0.0000, Val Accuracy: 99.52%
# Epoch 16, Batch 0, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 16, Batch 100, Train Loss: 0.0098, Train Accuracy: 99.22%
# Epoch 16, Batch 200, Train Loss: 0.0002, Train Accuracy: 100.00%
# Epoch 16, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 16, Val Loss: 0.0000, Val Accuracy: 99.35%
# Epoch 17, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 17, Batch 100, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 17, Batch 200, Train Loss: 0.0059, Train Accuracy: 99.22%
# Epoch 17, Batch 300, Train Loss: 0.0663, Train Accuracy: 99.22%
# Epoch 17, Val Loss: 0.0000, Val Accuracy: 99.46%
# Epoch 18, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 18, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 18, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 18, Batch 300, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 18, Val Loss: 0.0000, Val Accuracy: 99.42%
# Epoch 19, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 19, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 19, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 19, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 19, Val Loss: 0.0001, Val Accuracy: 99.34%
# Epoch 20, Batch 0, Train Loss: 0.0004, Train Accuracy: 100.00%
# Epoch 20, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 20, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 20, Batch 300, Train Loss: 0.0021, Train Accuracy: 100.00%
# Epoch 20, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 21, Batch 0, Train Loss: 0.0004, Train Accuracy: 100.00%
# Epoch 21, Batch 100, Train Loss: 0.0004, Train Accuracy: 100.00%
# Epoch 21, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 21, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 21, Val Loss: 0.0000, Val Accuracy: 99.42%
# Epoch 22, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 22, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 22, Batch 200, Train Loss: 0.0003, Train Accuracy: 100.00%
# Epoch 22, Batch 300, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 22, Val Loss: 0.0000, Val Accuracy: 99.30%
# Epoch 23, Batch 0, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 23, Batch 100, Train Loss: 0.0160, Train Accuracy: 99.22%
# Epoch 23, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 23, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 23, Val Loss: 0.0000, Val Accuracy: 99.38%
# Epoch 24, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 24, Batch 100, Train Loss: 0.0024, Train Accuracy: 100.00%
# Epoch 24, Batch 200, Train Loss: 0.0015, Train Accuracy: 100.00%
# Epoch 24, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 24, Val Loss: 0.0000, Val Accuracy: 99.35%
# Epoch 25, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 25, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 25, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 25, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 25, Val Loss: 0.0000, Val Accuracy: 99.30%
# Epoch 26, Batch 0, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 26, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 26, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 26, Batch 300, Train Loss: 0.0131, Train Accuracy: 99.22%
# Epoch 26, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 27, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 27, Batch 100, Train Loss: 0.0170, Train Accuracy: 99.22%
# Epoch 27, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 27, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 27, Val Loss: 0.0000, Val Accuracy: 99.50%
# Epoch 28, Batch 0, Train Loss: 0.0047, Train Accuracy: 100.00%
# Epoch 28, Batch 100, Train Loss: 0.0004, Train Accuracy: 100.00%
# Epoch 28, Batch 200, Train Loss: 0.0004, Train Accuracy: 100.00%
# Epoch 28, Batch 300, Train Loss: 0.0153, Train Accuracy: 99.22%
# Epoch 28, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 29, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 29, Batch 100, Train Loss: 0.0345, Train Accuracy: 98.44%
# Epoch 29, Batch 200, Train Loss: 0.0098, Train Accuracy: 99.22%
# Epoch 29, Batch 300, Train Loss: 0.0008, Train Accuracy: 100.00%
# Epoch 29, Val Loss: 0.0000, Val Accuracy: 99.46%
# Epoch 30, Batch 0, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 30, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 30, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 30, Batch 300, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 30, Val Loss: 0.0000, Val Accuracy: 99.38%
# Epoch 31, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 31, Batch 100, Train Loss: 0.0139, Train Accuracy: 99.22%
# Epoch 31, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 31, Batch 300, Train Loss: 0.0019, Train Accuracy: 100.00%
# Epoch 31, Val Loss: 0.0000, Val Accuracy: 99.38%
# Epoch 32, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 32, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 32, Batch 200, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 32, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 32, Val Loss: 0.0000, Val Accuracy: 99.44%
# Epoch 33, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 33, Batch 100, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 33, Batch 200, Train Loss: 0.0002, Train Accuracy: 100.00%
# Epoch 33, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 33, Val Loss: 0.0000, Val Accuracy: 99.38%
# Epoch 34, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 34, Batch 100, Train Loss: 0.0643, Train Accuracy: 99.22%
# Epoch 34, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 34, Batch 300, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 34, Val Loss: 0.0000, Val Accuracy: 99.52%
# Epoch 35, Batch 0, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 35, Batch 100, Train Loss: 0.0161, Train Accuracy: 99.22%
# Epoch 35, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 35, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 35, Val Loss: 0.0000, Val Accuracy: 99.43%
# Epoch 36, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 36, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 36, Batch 200, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 36, Batch 300, Train Loss: 0.0081, Train Accuracy: 99.22%
# Epoch 36, Val Loss: 0.0000, Val Accuracy: 99.38%
# Epoch 37, Batch 0, Train Loss: 0.0020, Train Accuracy: 100.00%
# Epoch 37, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 37, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 37, Batch 300, Train Loss: 0.0002, Train Accuracy: 100.00%
# Epoch 37, Val Loss: 0.0000, Val Accuracy: 99.47%
# Epoch 38, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 38, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 38, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 38, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 38, Val Loss: 0.0000, Val Accuracy: 99.47%
# Epoch 39, Batch 0, Train Loss: 0.0087, Train Accuracy: 99.22%
# Epoch 39, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 39, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 39, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 39, Val Loss: 0.0000, Val Accuracy: 99.45%
# Epoch 40, Batch 0, Train Loss: 0.0101, Train Accuracy: 99.22%
# Epoch 40, Batch 100, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 40, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 40, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 40, Val Loss: 0.0000, Val Accuracy: 99.48%
# Epoch 41, Batch 0, Train Loss: 0.0005, Train Accuracy: 100.00%
# Epoch 41, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 41, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 41, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 41, Val Loss: 0.0000, Val Accuracy: 99.46%
# Epoch 42, Batch 0, Train Loss: 0.0016, Train Accuracy: 100.00%
# Epoch 42, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 42, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 42, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 42, Val Loss: 0.0000, Val Accuracy: 99.41%
# Epoch 43, Batch 0, Train Loss: 0.0009, Train Accuracy: 100.00%
# Epoch 43, Batch 100, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 43, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 43, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 43, Val Loss: 0.0000, Val Accuracy: 99.48%
# Epoch 44, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 44, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 44, Batch 200, Train Loss: 0.0081, Train Accuracy: 100.00%
# Epoch 44, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 44, Val Loss: 0.0000, Val Accuracy: 99.48%
# Epoch 45, Batch 0, Train Loss: 0.0003, Train Accuracy: 100.00%
# Epoch 45, Batch 100, Train Loss: 0.0007, Train Accuracy: 100.00%
# Epoch 45, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 45, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 45, Val Loss: 0.0000, Val Accuracy: 99.44%
# Epoch 46, Batch 0, Train Loss: 0.0740, Train Accuracy: 99.22%
# Epoch 46, Batch 100, Train Loss: 0.0053, Train Accuracy: 100.00%
# Epoch 46, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 46, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 46, Val Loss: 0.0000, Val Accuracy: 99.49%
# Epoch 47, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 47, Batch 100, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 47, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 47, Batch 300, Train Loss: 0.0018, Train Accuracy: 100.00%
# Epoch 47, Val Loss: 0.0000, Val Accuracy: 99.43%
# Epoch 48, Batch 0, Train Loss: 0.0012, Train Accuracy: 100.00%
# Epoch 48, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 48, Batch 200, Train Loss: 0.0001, Train Accuracy: 100.00%
# Epoch 48, Batch 300, Train Loss: 0.0006, Train Accuracy: 100.00%
# Epoch 48, Val Loss: 0.0000, Val Accuracy: 99.47%
# Epoch 49, Batch 0, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 49, Batch 100, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 49, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 49, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 49, Val Loss: 0.0027, Val Accuracy: 99.38%
# Epoch 50, Batch 0, Train Loss: 0.0561, Train Accuracy: 97.66%
# Epoch 50, Batch 100, Train Loss: 0.0142, Train Accuracy: 99.22%
# Epoch 50, Batch 200, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 50, Batch 300, Train Loss: 0.0000, Train Accuracy: 100.00%
# Epoch 50, Val Loss: 0.0000, Val Accuracy: 99.52%

# %%
# 以下代碼執行後可以判斷你的作答是否正確，請勿修改
task_grader.q3_1_check(criterion, optimizer)
task_grader.q3_2_check(train_losses, val_losses, train_accs, val_accs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/3404309102.py in <cell line: 0>()
#       1 # 以下代碼執行後可以判斷你的作答是否正確，請勿修改
#       2 from sklearn.metrics import classification_report
# ----> 3 print(classification_report(test_true, test_preds))
#       4
#       5 task_grader.q3_1_check(criterion, optimizer)
#
# NameError: name 'test_true' is not defined

# %% [markdown]
# ### 可視化
#
# 以下是一段將數據集進行可視化的代碼，如果前面的代碼編寫正確，會顯示一行圖片，並顯示模型識別出該圖片是哪一個數字

# %%
def visualize_predictions(loader, model, title):
    images, true_labels = next(iter(loader))
    images = images.to(device)
    
    model.eval()
    with torch.no_grad():
        outputs = model(images)
        pred_probs = torch.softmax(outputs, dim=1)
        pred_labels = outputs.argmax(dim=1)
    
    images = images[:5].cpu()
    true_labels = true_labels[:5]
    pred_labels = pred_labels[:5].cpu()
    pred_probs = pred_probs[:5].cpu()
    
    plt.figure(figsize=(15, 3))
    plt.suptitle(title, fontsize=16)
    
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = images[i].squeeze()
        
        plt.imshow(img.numpy(), cmap='gray' if img.dim() == 2 else None)
        pred_prob = pred_probs[i][pred_labels[i]].item()
        plt.title(f"Prediction: {pred_labels[i].item()}, Answer: {true_labels[i].item()}", 
                 color='green' if pred_labels[i].item() == true_labels[i].item() else 'red')
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

visualize_predictions(val_loader, model, "Predictions")

# %% [markdown]
# ### 提交
#
# 以下代碼會生成一個 `submission.csv`，選手只需要在右側菜單中選擇 `Submit to competition > Submit` 就可以完成提交

# %%
import torch
import pandas as pd

test_images = torch.load('/kaggle/input/moai-2025-training/test_images.pt', weights_only=True)
test_images = (test_images.float() - test_images.float().mean()) /test_images.float().std()

model.eval()
with torch.no_grad():
    device = next(model.parameters()).device
    outputs = model(test_images.to(device))
    predictions = outputs.argmax(dim=1)

df_test = pd.DataFrame({"label": predictions.cpu().numpy()})
df_test.to_csv("submission.csv", index_label="id")
